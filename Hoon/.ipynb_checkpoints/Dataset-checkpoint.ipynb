# %% [markdown]
# # Dataset v1

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Data Load
train_df = pd.read_csv('../model/data/train.csv', index_col=0) # 캐글 데이터
gen_df = pd.read_csv('../model/data/gen_data_final998.csv', index_col=0) # 생성데이터

# 클래스명 통일
class_dict = {'협박 대화': 0, '갈취 대화':1, '직장 내 괴롭힘 대화':2, '기타 괴롭힘 대화':3, '일반 대화':4}

gen_df['topic'] = '일반 대화'
gen_df = gen_df.rename(columns={'topic':'class'})

# Trainset 취합
data_df = pd.concat([train_df, gen_df], ignore_index=True)

# 클래스명 정수 변환
data_df['class'] = data_df['class'].apply(lambda x: class_dict[x])

# %%
data_df
# Out:
#       class                                       conversation
# 0         0  지금 너 스스로를 죽여달라고 애원하는 것인가?\n 아닙니다. 죄송합니다.\n 죽을 ...
# 1         0  길동경찰서입니다.\n9시 40분 마트에 폭발물을 설치할거다.\n네?\n똑바로 들어 ...
# 2         3  너 되게 귀여운거 알지? 나보다 작은 남자는 첨봤어.\n그만해. 니들 놀리는거 재미...
# 3         1  어이 거기\n예??\n너 말이야 너. 이리 오라고\n무슨 일.\n너 옷 좋아보인다?...
# 4         1  저기요 혹시 날이 너무 뜨겁잖아요? 저희 회사에서 이 선크림 파는데 한 번 손등에 ...
# ...     ...                                                ...
# 4943      4  너 중학교 때 HOT 팬 아니었어? 방에 브로마이드 붙여놓고 그랬잖아.\n헐 어떻게...
# 4944      4  대학교 1학년 때 갔던 MT 기억나? 술 마시고 게임하다가 필름 끊겼잖아.\n와 그...
# 4945      4  나 어릴 때 살던 동네 골목길 사진을 우연히 봤는데 기분이 이상하더라.\n많이 변했...
# 4946      4  2002 월드컵 때 거리 응원 나갔던 거 생각하면 아직도 소름 돋아.\n와 맞아! ...
# 4947      4  대학교 졸업식 날 기억나? 다 같이 학사모 던지고 사진 찍고.\n그럼! 시원섭섭했지...
#
# [4948 rows x 2 columns]

# %%
# y_train의 값 분포 시각화
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.countplot(x=data_df['class'])
plt.title('Distribution of class')
plt.xlabel('Class')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# 중복데이터!!!
data_df[data_df.duplicated()]
# Out:
#       class                                       conversation
# 392       3  병신이 아이스크림 먹게 돼 있냐?\n난 먹으면 안 돼? 그만 좀 해.\n당연히 안 ...
# 523       2  과장님. 저 이번에 휴가 좀 갔다와도 되겠습니까.?\n휴가? 왜??\n좀 쉬다가 오...
# 789       3  야 얘 이 쪽 손가락 세 개밖에 없다\n엥 손가락이 세개밖에 없을 수가 있어?\n봐...
# 824       3  이야 내동생 여자친구한테 편지쓰네?\n 아 형 돌려줘.\n 어디보자. 사랑하는 여친...
# 869       2  지현씨 나 소개팅 좀 시켜줘봐\n네? 저 주변에 아는 사람이 없어서요\n아 상사라 ...
# ...     ...                                                ...
# 3797      3  너 이번 방학 때 쌍꺼풀 수술 하고왔지?\n아닌데?\n아니긴 뭐가 아니야. 눈이 이...
# 3798      3  안녕하세요 지금 먹방 촬영중인데 촬영가능할까요?\n안돼요\n한번만 안될까요?\n안돼...
# 3855      3  그 소문 진짜야? 너가 다른 애들 뒷담화하고 다녔다며?\n응? 나 그런 적 없는데?...
# 3874      3  야 니 왤캐 못생겼냐?\n뭐라그랬냐?\n으 나 보고 말하지마 니 얼굴보면 토나올거 ...
# 3928      3  새파랗게 젊은게 어디 여길 앉아있어\n저 임산부에요\n사지 멀쩡한게! 임신이 벼슬이...
#
# [104 rows x 2 columns]

# %%
# 중복제거
data_df.drop_duplicates(inplace=True)
data_df
# Out:
#       class                                       conversation
# 0         0  지금 너 스스로를 죽여달라고 애원하는 것인가?\n 아닙니다. 죄송합니다.\n 죽을 ...
# 1         0  길동경찰서입니다.\n9시 40분 마트에 폭발물을 설치할거다.\n네?\n똑바로 들어 ...
# 2         3  너 되게 귀여운거 알지? 나보다 작은 남자는 첨봤어.\n그만해. 니들 놀리는거 재미...
# 3         1  어이 거기\n예??\n너 말이야 너. 이리 오라고\n무슨 일.\n너 옷 좋아보인다?...
# 4         1  저기요 혹시 날이 너무 뜨겁잖아요? 저희 회사에서 이 선크림 파는데 한 번 손등에 ...
# ...     ...                                                ...
# 4943      4  너 중학교 때 HOT 팬 아니었어? 방에 브로마이드 붙여놓고 그랬잖아.\n헐 어떻게...
# 4944      4  대학교 1학년 때 갔던 MT 기억나? 술 마시고 게임하다가 필름 끊겼잖아.\n와 그...
# 4945      4  나 어릴 때 살던 동네 골목길 사진을 우연히 봤는데 기분이 이상하더라.\n많이 변했...
# 4946      4  2002 월드컵 때 거리 응원 나갔던 거 생각하면 아직도 소름 돋아.\n와 맞아! ...
# 4947      4  대학교 졸업식 날 기억나? 다 같이 학사모 던지고 사진 찍고.\n그럼! 시원섭섭했지...
#
# [4844 rows x 2 columns]

# %%
# Target 분리
df_X = data_df["conversation"]
df_y = data_df['class']

# %%
df_X.shape, df_y.shape
# Out:
# ((4844,), (4844,))

# %%
df_X = np.array(df_X)
df_y = np.array(df_y)

# %%
df_X.shape, df_y.shape
# Out:
# ((4844,), (4844,))

# %%
# Validation Set 분리
X_train, X_val, y_train, y_val = train_test_split(df_X, df_y,
                                                    test_size=0.2,
                                                    random_state=42, 
                                                    stratify=df_y)

# %%
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((3875,), (969,), (3875,), (969,))

# %%
# y_train의 값 분포 시각화
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.countplot(x=y_train)
plt.title('Distribution of y_train')
plt.xlabel('Class')
plt.ylabel('Count')

# y_test의 값 분포 시각화
plt.subplot(1, 2, 2)
sns.countplot(x=y_val)
plt.title('Distribution of y_val')
plt.xlabel('Class')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
# Trainset 합치기
train = {'class': y_train, 'conversation': X_train}
trainset = pd.DataFrame(train)
trainset
# Out:
#       class                                       conversation
# 0         0  너네 딸 어디있어?\n 누구시죠?\n 너네 딸이 우리 딸 이렇게 만들었다고! 당장 ...
# 1         0  입금받았으니 물건 빨리 보내시죠\n 당분간 바빠서 그래요\n 장난하십니까.벌써 몇번...
# 2         2  이사원 이업무좀 내일까지 할수있나\n저 지금 하고있는거도있고 내일까지는 힘들거같습니...
# 3         1  안녕 꼬마야 몇살이야\n안녕하세요 6살이요\n손에 든건뭐야?\n돈이에요 엄마가 애호...
# 4         1  아니 이자가 왜 이리 늘어요? 너무한거 아니에요\n뭐 새끼야 애초에 돈을 빌렸으면 ...
# ...     ...                                                ...
# 3870      4  이상으로 이번 프로젝트의 주요 성과를 말씀드렸습니다. 질문 있으시면 부탁드립니다.\...
# 3871      1  저기요 저 1000원만 주실 수 있나요?\n네? 제가 왜요?\n제가 버스비가 없어서...
# 3872      1  내가 너 도와줬으니까 돈 줘\n그런게 어딨어 밥만 사줄게\n돈 내놓으라고\n왜 밥으...
# 3873      3  병신이 아이스크림 먹게 돼 있냐?\n난 먹으면 안 돼? 그만 좀 해.\n당연히 안 ...
# 3874      4  와 이 피규어 한정판이래! 당장 사야 해!\n잠깐만. 너 저번 달에도 한정판 산다고...
#
# [3875 rows x 2 columns]

# %%
# validationset합치기
validation = {'class': y_val, 'conversation': X_val}
val_set = pd.DataFrame(validation)
val_set
# Out:
#      class                                       conversation
# 0        3  최민철 너 내일까지 나 대신 내 깜지 쫌 써와라.\n응? 그거 선생님께서 오늘 시험...
# 1        3  고모 오셨어요?\n그래 너 이번 모의고사에서 몇 등급 받았니?\n5등급이요.\n5등...
# 2        1  야 마트가서 먹을것 좀 사와.\n돈은요?\n아 담에 줄게. 일단 사와 새끼야.\n저...
# 3        2  사장님 저기 말할게 있는데요\n뭔데 임마\n아니 우리 게임회사는 전체이용가 게임이잖...
# 4        1  이 사장님 이거 오랜만입니다?\n아.자네 어쩐 일인가.\n어쩐 일이냐뇨 섭섭하네요....
# ..     ...                                                ...
# 964      2  이게뭐야 김사원 똑바로 안해?\n뭐가요\n말대꾸하지마\n예?\n이게어디서\n죄송합니...
# 965      1  뒤로 횡령하신 전적이 있으시던데?\n어디서 뭘 봤는지 모르겠지만 잘못 봤어.\n동료...
# 966      0  네? 진짜 작작하고 그만하세요 경찰에 신고하기전에\n너 안그래도 경찰에 신고 할거잖...
# 967      1  어이 너희 집 어딘지 이제 아는데.\n선생님 제발 우리 집에는 오지 마세요.\n그럼...
# 968      2  우리 오늘 점심은 장어 먹읍시다\n네 장어요?\n왜 장어 못먹나 먹고 기운내게\n아...
#
# [969 rows x 2 columns]

# %%
# csv파일로 저장
trainset.to_csv('trainset_v1.csv', index=False)
val_set.to_csv('valset_v1.csv', index=False)

# %%
# 저장된 train set파일 확인
temp = pd.read_csv('trainset_v1.csv')
temp
# Out:
#       class                                       conversation
# 0         0  너네 딸 어디있어?\n 누구시죠?\n 너네 딸이 우리 딸 이렇게 만들었다고! 당장 ...
# 1         0  입금받았으니 물건 빨리 보내시죠\n 당분간 바빠서 그래요\n 장난하십니까.벌써 몇번...
# 2         2  이사원 이업무좀 내일까지 할수있나\n저 지금 하고있는거도있고 내일까지는 힘들거같습니...
# 3         1  안녕 꼬마야 몇살이야\n안녕하세요 6살이요\n손에 든건뭐야?\n돈이에요 엄마가 애호...
# 4         1  아니 이자가 왜 이리 늘어요? 너무한거 아니에요\n뭐 새끼야 애초에 돈을 빌렸으면 ...
# ...     ...                                                ...
# 3870      4  이상으로 이번 프로젝트의 주요 성과를 말씀드렸습니다. 질문 있으시면 부탁드립니다.\...
# 3871      1  저기요 저 1000원만 주실 수 있나요?\n네? 제가 왜요?\n제가 버스비가 없어서...
# 3872      1  내가 너 도와줬으니까 돈 줘\n그런게 어딨어 밥만 사줄게\n돈 내놓으라고\n왜 밥으...
# 3873      3  병신이 아이스크림 먹게 돼 있냐?\n난 먹으면 안 돼? 그만 좀 해.\n당연히 안 ...
# 3874      4  와 이 피규어 한정판이래! 당장 사야 해!\n잠깐만. 너 저번 달에도 한정판 산다고...
#
# [3875 rows x 2 columns]

# %%
# 저장된 validation set파일 확인
temp = pd.read_csv('valset_v1.csv')
temp
# Out:
#      class                                       conversation
# 0        3  최민철 너 내일까지 나 대신 내 깜지 쫌 써와라.\n응? 그거 선생님께서 오늘 시험...
# 1        3  고모 오셨어요?\n그래 너 이번 모의고사에서 몇 등급 받았니?\n5등급이요.\n5등...
# 2        1  야 마트가서 먹을것 좀 사와.\n돈은요?\n아 담에 줄게. 일단 사와 새끼야.\n저...
# 3        2  사장님 저기 말할게 있는데요\n뭔데 임마\n아니 우리 게임회사는 전체이용가 게임이잖...
# 4        1  이 사장님 이거 오랜만입니다?\n아.자네 어쩐 일인가.\n어쩐 일이냐뇨 섭섭하네요....
# ..     ...                                                ...
# 964      2  이게뭐야 김사원 똑바로 안해?\n뭐가요\n말대꾸하지마\n예?\n이게어디서\n죄송합니...
# 965      1  뒤로 횡령하신 전적이 있으시던데?\n어디서 뭘 봤는지 모르겠지만 잘못 봤어.\n동료...
# 966      0  네? 진짜 작작하고 그만하세요 경찰에 신고하기전에\n너 안그래도 경찰에 신고 할거잖...
# 967      1  어이 너희 집 어딘지 이제 아는데.\n선생님 제발 우리 집에는 오지 마세요.\n그럼...
# 968      2  우리 오늘 점심은 장어 먹읍시다\n네 장어요?\n왜 장어 못먹나 먹고 기운내게\n아...
#
# [969 rows x 2 columns]

# %% [markdown]
# # Dataset v2

# %%
# Data Load
train_df = pd.read_csv('../model/data/train.csv', index_col=0) # 캐글 데이터
gen_df = pd.read_csv('../model/data/gen_data_final998.csv', index_col=0) # 생성데이터

# 클래스명 통일
class_dict = {'협박 대화': 0, '갈취 대화':1, '직장 내 괴롭힘 대화':2, '기타 괴롭힘 대화':3, '일반 대화':4}

gen_df['topic'] = '일반 대화'
gen_df = gen_df.rename(columns={'topic':'class'})

# Trainset 취합
data_df = pd.concat([train_df, gen_df], ignore_index=True)

# 클래스명 정수 변환
data_df['class'] = data_df['class'].apply(lambda x: class_dict[x])

# %%
data_df
# Out:
#       class                                       conversation
# 0         0  지금 너 스스로를 죽여달라고 애원하는 것인가?\n 아닙니다. 죄송합니다.\n 죽을 ...
# 1         0  길동경찰서입니다.\n9시 40분 마트에 폭발물을 설치할거다.\n네?\n똑바로 들어 ...
# 2         3  너 되게 귀여운거 알지? 나보다 작은 남자는 첨봤어.\n그만해. 니들 놀리는거 재미...
# 3         1  어이 거기\n예??\n너 말이야 너. 이리 오라고\n무슨 일.\n너 옷 좋아보인다?...
# 4         1  저기요 혹시 날이 너무 뜨겁잖아요? 저희 회사에서 이 선크림 파는데 한 번 손등에 ...
# ...     ...                                                ...
# 4943      4  너 중학교 때 HOT 팬 아니었어? 방에 브로마이드 붙여놓고 그랬잖아.\n헐 어떻게...
# 4944      4  대학교 1학년 때 갔던 MT 기억나? 술 마시고 게임하다가 필름 끊겼잖아.\n와 그...
# 4945      4  나 어릴 때 살던 동네 골목길 사진을 우연히 봤는데 기분이 이상하더라.\n많이 변했...
# 4946      4  2002 월드컵 때 거리 응원 나갔던 거 생각하면 아직도 소름 돋아.\n와 맞아! ...
# 4947      4  대학교 졸업식 날 기억나? 다 같이 학사모 던지고 사진 찍고.\n그럼! 시원섭섭했지...
#
# [4948 rows x 2 columns]

# %%
gen_df2 = pd.read_csv('./data/gen_data2_279.csv', index_col=0) # 생성데이터
gen_df2
# Out:
#                                                       conversation
# topic
# 영화 속 폭력적인 장면 리뷰  야 어제 그 영화 액션 장면 진짜 화려하더라 근데 너무 잔인하지 않았어? 망치로 사...
# 영화 속 위협적인 대사 리뷰  그 영화에서 '네 모든 걸 빼앗아주겠다'는 악당 대사 들었어? 진짜 섬뜩하더라 어떻...
# 영화 속 폭력적인 장면 리뷰  야 너 그 문제의 영화 봤어? 폭력 묘사가 상상 초월이라던데 얼마나 심해?\r\n응...
# 영화 속 위협적인 대사 리뷰  그 영화 주인공 마지막 대사 기억나? '이제 끝이다'라고 하는 거 뭔가 뭉클하더라 ...
# 영화 속 폭력적인 장면 리뷰  최근 영화들 왜 이렇게 폭력적인 장면이 많이 나오는 것 같지? 보기가 점점 힘들어져...
# ...                                                            ...
# 싸웠던 친구와 화해       야! 드디어 걔랑 화해했다며? 완전 축하해!\r\n응! 네 덕분에 용기내서 먼저 연...
# 싸웠던 친구와 화해       아직도 그 친구랑 서먹서먹해?\r\n솔직히 아직 좀 그래. 먼저 연락은 했는데 답장...
# 싸웠던 친구와 화해       너 요즘 얼굴이 밝아졌네? 혹시 좋은 일 있어?\r\n응! 드디어 걔랑 완전히 화해...
# 싸웠던 친구와 화해       야... 걔랑 다시 어색해진 건 아니지?\r\n아니! 이제 완전히 풀었어. 오히려 ...
# 싸웠던 친구와 화해       너 며칠 전에 걔한테 연락했다며? 잘 됐어?\r\n응! 처음엔 좀 어색했는데 이야기...
#
# [279 rows x 1 columns]

# %%
gen_df2['topic'] = '일반 대화'
gen_df2 = gen_df2.rename(columns={'topic':'class'})

gen_df2
# Out:
#                                                       conversation  class
# topic
# 영화 속 폭력적인 장면 리뷰  야 어제 그 영화 액션 장면 진짜 화려하더라 근데 너무 잔인하지 않았어? 망치로 사...  일반 대화
# 영화 속 위협적인 대사 리뷰  그 영화에서 '네 모든 걸 빼앗아주겠다'는 악당 대사 들었어? 진짜 섬뜩하더라 어떻...  일반 대화
# 영화 속 폭력적인 장면 리뷰  야 너 그 문제의 영화 봤어? 폭력 묘사가 상상 초월이라던데 얼마나 심해?\r\n응...  일반 대화
# 영화 속 위협적인 대사 리뷰  그 영화 주인공 마지막 대사 기억나? '이제 끝이다'라고 하는 거 뭔가 뭉클하더라 ...  일반 대화
# 영화 속 폭력적인 장면 리뷰  최근 영화들 왜 이렇게 폭력적인 장면이 많이 나오는 것 같지? 보기가 점점 힘들어져...  일반 대화
# ...                                                            ...    ...
# 싸웠던 친구와 화해       야! 드디어 걔랑 화해했다며? 완전 축하해!\r\n응! 네 덕분에 용기내서 먼저 연...  일반 대화
# 싸웠던 친구와 화해       아직도 그 친구랑 서먹서먹해?\r\n솔직히 아직 좀 그래. 먼저 연락은 했는데 답장...  일반 대화
# 싸웠던 친구와 화해       너 요즘 얼굴이 밝아졌네? 혹시 좋은 일 있어?\r\n응! 드디어 걔랑 완전히 화해...  일반 대화
# 싸웠던 친구와 화해       야... 걔랑 다시 어색해진 건 아니지?\r\n아니! 이제 완전히 풀었어. 오히려 ...  일반 대화
# 싸웠던 친구와 화해       너 며칠 전에 걔한테 연락했다며? 잘 됐어?\r\n응! 처음엔 좀 어색했는데 이야기...  일반 대화
#
# [279 rows x 2 columns]

# %%
# 클래스명 정수 변환
gen_df2['class'] = gen_df2['class'].apply(lambda x: class_dict[x])
gen_df2
# Out:
#                                                       conversation  class
# topic
# 영화 속 폭력적인 장면 리뷰  야 어제 그 영화 액션 장면 진짜 화려하더라 근데 너무 잔인하지 않았어? 망치로 사...      4
# 영화 속 위협적인 대사 리뷰  그 영화에서 '네 모든 걸 빼앗아주겠다'는 악당 대사 들었어? 진짜 섬뜩하더라 어떻...      4
# 영화 속 폭력적인 장면 리뷰  야 너 그 문제의 영화 봤어? 폭력 묘사가 상상 초월이라던데 얼마나 심해?\r\n응...      4
# 영화 속 위협적인 대사 리뷰  그 영화 주인공 마지막 대사 기억나? '이제 끝이다'라고 하는 거 뭔가 뭉클하더라 ...      4
# 영화 속 폭력적인 장면 리뷰  최근 영화들 왜 이렇게 폭력적인 장면이 많이 나오는 것 같지? 보기가 점점 힘들어져...      4
# ...                                                            ...    ...
# 싸웠던 친구와 화해       야! 드디어 걔랑 화해했다며? 완전 축하해!\r\n응! 네 덕분에 용기내서 먼저 연...      4
# 싸웠던 친구와 화해       아직도 그 친구랑 서먹서먹해?\r\n솔직히 아직 좀 그래. 먼저 연락은 했는데 답장...      4
# 싸웠던 친구와 화해       너 요즘 얼굴이 밝아졌네? 혹시 좋은 일 있어?\r\n응! 드디어 걔랑 완전히 화해...      4
# 싸웠던 친구와 화해       야... 걔랑 다시 어색해진 건 아니지?\r\n아니! 이제 완전히 풀었어. 오히려 ...      4
# 싸웠던 친구와 화해       너 며칠 전에 걔한테 연락했다며? 잘 됐어?\r\n응! 처음엔 좀 어색했는데 이야기...      4
#
# [279 rows x 2 columns]

# %%
# Trainset 취합
data_df = pd.concat([data_df, gen_df2], ignore_index=True)
data_df
# Out:
#       class                                       conversation
# 0         0  지금 너 스스로를 죽여달라고 애원하는 것인가?\n 아닙니다. 죄송합니다.\n 죽을 ...
# 1         0  길동경찰서입니다.\n9시 40분 마트에 폭발물을 설치할거다.\n네?\n똑바로 들어 ...
# 2         3  너 되게 귀여운거 알지? 나보다 작은 남자는 첨봤어.\n그만해. 니들 놀리는거 재미...
# 3         1  어이 거기\n예??\n너 말이야 너. 이리 오라고\n무슨 일.\n너 옷 좋아보인다?...
# 4         1  저기요 혹시 날이 너무 뜨겁잖아요? 저희 회사에서 이 선크림 파는데 한 번 손등에 ...
# ...     ...                                                ...
# 5222      4  야! 드디어 걔랑 화해했다며? 완전 축하해!\r\n응! 네 덕분에 용기내서 먼저 연...
# 5223      4  아직도 그 친구랑 서먹서먹해?\r\n솔직히 아직 좀 그래. 먼저 연락은 했는데 답장...
# 5224      4  너 요즘 얼굴이 밝아졌네? 혹시 좋은 일 있어?\r\n응! 드디어 걔랑 완전히 화해...
# 5225      4  야... 걔랑 다시 어색해진 건 아니지?\r\n아니! 이제 완전히 풀었어. 오히려 ...
# 5226      4  너 며칠 전에 걔한테 연락했다며? 잘 됐어?\r\n응! 처음엔 좀 어색했는데 이야기...
#
# [5227 rows x 2 columns]

# %%
# 중복제거
data_df.drop_duplicates(inplace=True)
data_df
# Out:
#       class                                       conversation
# 0         0  지금 너 스스로를 죽여달라고 애원하는 것인가?\n 아닙니다. 죄송합니다.\n 죽을 ...
# 1         0  길동경찰서입니다.\n9시 40분 마트에 폭발물을 설치할거다.\n네?\n똑바로 들어 ...
# 2         3  너 되게 귀여운거 알지? 나보다 작은 남자는 첨봤어.\n그만해. 니들 놀리는거 재미...
# 3         1  어이 거기\n예??\n너 말이야 너. 이리 오라고\n무슨 일.\n너 옷 좋아보인다?...
# 4         1  저기요 혹시 날이 너무 뜨겁잖아요? 저희 회사에서 이 선크림 파는데 한 번 손등에 ...
# ...     ...                                                ...
# 5222      4  야! 드디어 걔랑 화해했다며? 완전 축하해!\r\n응! 네 덕분에 용기내서 먼저 연...
# 5223      4  아직도 그 친구랑 서먹서먹해?\r\n솔직히 아직 좀 그래. 먼저 연락은 했는데 답장...
# 5224      4  너 요즘 얼굴이 밝아졌네? 혹시 좋은 일 있어?\r\n응! 드디어 걔랑 완전히 화해...
# 5225      4  야... 걔랑 다시 어색해진 건 아니지?\r\n아니! 이제 완전히 풀었어. 오히려 ...
# 5226      4  너 며칠 전에 걔한테 연락했다며? 잘 됐어?\r\n응! 처음엔 좀 어색했는데 이야기...
#
# [5123 rows x 2 columns]

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.countplot(x=data_df['class'])
plt.title('Distribution of class')
plt.xlabel('Class')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Target 분리
df_X = data_df["conversation"]
df_y = data_df['class']

# %%
df_X.shape, df_y.shape
# Out:
# ((5123,), (5123,))

# %%
df_X = np.array(df_X)
df_y = np.array(df_y)

# %%
df_X.shape, df_y.shape
# Out:
# ((5123,), (5123,))

# %%
# Validation Set 분리
X_train, X_val, y_train, y_val = train_test_split(df_X, df_y,
                                                    test_size=0.2,
                                                    random_state=42, 
                                                    stratify=df_y)

# %%
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((4098,), (1025,), (4098,), (1025,))

# %%
# y_train의 값 분포 시각화
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.countplot(x=y_train)
plt.title('Distribution of y_train')
plt.xlabel('Class')
plt.ylabel('Count')

# y_test의 값 분포 시각화
plt.subplot(1, 2, 2)
sns.countplot(x=y_val)
plt.title('Distribution of y_val')
plt.xlabel('Class')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
# Trainset 합치기
train = {'class': y_train, 'conversation': X_train}
trainset = pd.DataFrame(train)
trainset
# Out:
#       class                                       conversation
# 0         0  우리 한 약속은 잊지 않았겠지?\n우리가 한 약속이라니?\n우리 어릴 때 한 약속 ...
# 1         2  김사원\n대리님 왜 그러세요?\n이거 오늘까지 제출해야 하는데 좀 해줄래?\n네? ...
# 2         3  거기 아래 공기는 어때? 호빗 같이 작은 성철아?\n 근데 너 이 정도로 작으면 장...
# 3         1  돈 좀 없냐?\n 없어요.\n 너 알바비 받은 거 있잖아.\n 썼어요. 없어요.\n...
# 4         1  담배 좀 빌립시다.\n학생들같은데 그냥 가라.\n거 같이 좀 핍시다.\n학생이 무슨...
# ...     ...                                                ...
# 4093      2  자료 다 만들었어요?\n네 방금 메일로 보내드렸어요\n이렇게 빨리 할 게 아닌데 대...
# 4094      2  어머어머 효정씨 살찐것좀봐\n네?\n아니 업무가 편한가? \n아니요.그건아닌데\n업...
# 4095      4  요즘 회사 일 때문에 개인적인 시간이 너무 부족한 것 같아요.\n저도 마찬가지예요....
# 4096      1  이번 한 번만 더 싸게 물건 넘기면 되는 거야. 알겠지?\n이번에도 이 가격으로 계...
# 4097      4  그 느와르 영화 봤는데 어둠의 세계를 너무 현실적으로 그려서 좀 충격적이었어. 폭력...
#
# [4098 rows x 2 columns]

# %%
# validationset합치기
validation = {'class': y_val, 'conversation': X_val}
val_set = pd.DataFrame(validation)
val_set
# Out:
#       class                                       conversation
# 0         0  아무도 없는 거리에서 너 칼로 쑤셔 죽일거야.\n죄송합니다.\n칼로 널 죽이고 너 ...
# 1         4  우리 내일 모여서 중간 결과 공유하는 거 어때?\n또 모여요? 그냥 각자 하고 나중...
# 2         3  님 롤 존나 못하네요\n니새끼보다는 잘하는 것 같은데요 \n스킬 못 맞추는 꼬라지\...
# 3         2  지수씨는 어쩜 그렇게 잘먹을까?\n네??\n아니 보고있으면 너무 잘먹어서 기빨린다 ...
# 4         1  형! 형! 돈좀있어?\n저 저요.?\n여기 형말고 누가 있어? 형 얼마 있어?\n저...
# ...     ...                                                ...
# 1020      3  야 저기 사마귀있다\n사마귀? 잡아봐 !! 여자애들 놀리자\n아 그래 재밌겠다\n야...
# 1021      4  야 혹시 네 신발 중에 내가 오늘 잠깐 신을 만한 편한 거 있을까? 물론 불편하면 ...
# 1022      2  야 술 받으라고!\n 죄송합니다. 한 잔 받겠습니다.\n 너는 어째 회사 안이나 밖...
# 1023      3  원투 원투 야 똑바로 서\n으 으윽 그만해\n아이씨 서 있어봐 좀\n아프다고!\n어...
# 1024      4  혹시 최근에 자신에게 주는 선물로 만족스러운 소비를 하신 거 있으세요?\n저는 얼마...
#
# [1025 rows x 2 columns]

# %%
# csv파일로 저장
trainset.to_csv('trainset_v2.csv', index=False)
val_set.to_csv('valset_v2.csv', index=False)

# %%
# 저장된 train set파일 확인
temp = pd.read_csv('trainset_v2.csv')
temp
# Out:
#       class                                       conversation
# 0         0  우리 한 약속은 잊지 않았겠지?\n우리가 한 약속이라니?\n우리 어릴 때 한 약속 ...
# 1         2  김사원\n대리님 왜 그러세요?\n이거 오늘까지 제출해야 하는데 좀 해줄래?\n네? ...
# 2         3  거기 아래 공기는 어때? 호빗 같이 작은 성철아?\n 근데 너 이 정도로 작으면 장...
# 3         1  돈 좀 없냐?\n 없어요.\n 너 알바비 받은 거 있잖아.\n 썼어요. 없어요.\n...
# 4         1  담배 좀 빌립시다.\n학생들같은데 그냥 가라.\n거 같이 좀 핍시다.\n학생이 무슨...
# ...     ...                                                ...
# 4093      2  자료 다 만들었어요?\n네 방금 메일로 보내드렸어요\n이렇게 빨리 할 게 아닌데 대...
# 4094      2  어머어머 효정씨 살찐것좀봐\n네?\n아니 업무가 편한가? \n아니요.그건아닌데\n업...
# 4095      4  요즘 회사 일 때문에 개인적인 시간이 너무 부족한 것 같아요.\n저도 마찬가지예요....
# 4096      1  이번 한 번만 더 싸게 물건 넘기면 되는 거야. 알겠지?\n이번에도 이 가격으로 계...
# 4097      4  그 느와르 영화 봤는데 어둠의 세계를 너무 현실적으로 그려서 좀 충격적이었어. 폭력...
#
# [4098 rows x 2 columns]

# %%
# 저장된 validation set파일 확인
temp = pd.read_csv('valset_v2.csv')
temp
# Out:
#       class                                       conversation
# 0         0  아무도 없는 거리에서 너 칼로 쑤셔 죽일거야.\n죄송합니다.\n칼로 널 죽이고 너 ...
# 1         4  우리 내일 모여서 중간 결과 공유하는 거 어때?\n또 모여요? 그냥 각자 하고 나중...
# 2         3  님 롤 존나 못하네요\n니새끼보다는 잘하는 것 같은데요 \n스킬 못 맞추는 꼬라지\...
# 3         2  지수씨는 어쩜 그렇게 잘먹을까?\n네??\n아니 보고있으면 너무 잘먹어서 기빨린다 ...
# 4         1  형! 형! 돈좀있어?\n저 저요.?\n여기 형말고 누가 있어? 형 얼마 있어?\n저...
# ...     ...                                                ...
# 1020      3  야 저기 사마귀있다\n사마귀? 잡아봐 !! 여자애들 놀리자\n아 그래 재밌겠다\n야...
# 1021      4  야 혹시 네 신발 중에 내가 오늘 잠깐 신을 만한 편한 거 있을까? 물론 불편하면 ...
# 1022      2  야 술 받으라고!\n 죄송합니다. 한 잔 받겠습니다.\n 너는 어째 회사 안이나 밖...
# 1023      3  원투 원투 야 똑바로 서\n으 으윽 그만해\n아이씨 서 있어봐 좀\n아프다고!\n어...
# 1024      4  혹시 최근에 자신에게 주는 선물로 만족스러운 소비를 하신 거 있으세요?\n저는 얼마...
#
# [1025 rows x 2 columns]
