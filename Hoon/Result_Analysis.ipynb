# %% [markdown]
# # Class Distribution on Submission Result

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
def check_distribution(file_path):
    submission = pd.read_csv(file_path)
    plt.figure(figsize=(10, 5))
    ax = sns.countplot(x=submission['target'])
    plt.title('Distribution of class')
    plt.xlabel('Class')
    plt.ylabel('Count')
    
    # 막대 위에 수치값 표기
    for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x() + p.get_width() / 2., height + 3, f'{height}', ha='center', size=9)
    plt.show()

# %%
check_distribution('./submissions/bert_klue_sub_070583.csv')

# %%
check_distribution('./submissions/bert_klue_sub_070838.csv')

# %%
check_distribution('./submissions/bert_vanilla_sub_062850.csv')

# %%
check_distribution('./submissions/bert_vanilla_sub_065434.csv')

# %%
check_distribution('./submissions/submission_3_064339.csv')

# %%
check_distribution('./submissions/submission_numeric_059410.csv')

# %%
check_distribution('./submissions/sub_preBERT_withDense_072262.csv')

# %% [markdown]
# ---

# %%
check_distribution('./submissions/hoon_test01_071193.csv')

# %%
check_distribution('./submissions/hoon_test02_loadedW_070765.csv')

# %%
check_distribution('./submissions/bert_klue_alllayer_rm_071823.csv')

# %%
check_distribution('./submissions/bert_klue_rm_aeda_071562.csv')

# %%
check_distribution('./submissions/bert_klue_rm_eda_074373.csv')

# %%
check_distribution('./submissions/bert_klue_060260.csv')
